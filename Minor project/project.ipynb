# %%
#importing important files |
import pandas as pd
import numpy as np
import csv
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.

#loading the csv file and storing it in the variable "tmbd_data"
tmdb_data = pd.read_csv(r'C:\Users\Shreya Ananya\Downloads\tmdb-movies (1).csv')

#printing first five rows with defined columns of tmdb-movies database
tmdb_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#creating a list of columb to be deleted
del_col=[ 'id', 'imdb_id', 'popularity', 'budget_adj', 'revenue_adj', 'homepage', 'keywords', 'overview', 'vote_count', 'vote_average']

#deleting the columns
tmdb_data= tmdb_data.drop(del_col,1)

#previewing the new dataset
tmdb_data.head(4)
# Out:
#       budget     revenue                original_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# 3  Every generation has a story.      136
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# ...

# %%
rows, col = tmdb_data.shape
#We need to reduce the count of row by one as contain header row also.
print('There are {} total entries of movies and {} no.of columns in it.'.format(rows-1, col))
# Out:
# There are 10865 total entries of movies and 11 no.of columns in it.

# %%
# creating a seperate list of revenue and budget column
temp_list=['budget', 'revenue']

#this will replace all the value from '0' to NAN in the list
tmdb_data[temp_list] = tmdb_data[temp_list].replace(0, np.NAN)

#Removing all the row which has NaN value in temp_list 
tmdb_data.dropna(subset = temp_list, inplace = True)

rows, col = tmdb_data.shape
print('So after removing such entries, we now have only {} no.of movies.'.format(rows-1))
# Out:
# So after removing such entries, we now have only 3854 no.of movies.

# %%
tmdb_data.release_date = pd.to_datetime(tmdb_data['release_date'])

# %%
# printing the changed dataset
tmdb_data.head(3)
# Out:
#         budget       revenue      original_title  \
# 0  150000000.0  1.513529e+09      Jurassic World
# 1  150000000.0  3.784364e+08  Mad Max: Fury Road
# 2  110000000.0  2.952382e+08           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
#
#                       tagline  runtime  \
# 0           The park is open.      124
# 1          What a Lovely Day.      120
# 2  One Choice Can Destroy You      119
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# ...

# %%
#replacing 0 with NaN of runtime column in the dataset
tmdb_data['runtime'] =tmdb_data['runtime'].replace(0, np.NAN)

# %%
#printing the data type of the data set
tmdb_data.dtypes
# Out:
# budget                         float64
# revenue                        float64
# original_title                  object
# cast                            object
# director                        object
# tagline                         object
# runtime                          int64
# genres                          object
# production_companies            object
# release_date            datetime64[ns]
# release_year                     int64
# dtype: object

# %%
change_type=['budget', 'revenue']
#changing data type
tmdb_data[change_type]=tmdb_data[change_type].applymap(np.int64)
#printing the changed information
tmdb_data.dtypes
# Out:
# budget                           int64
# revenue                          int64
# original_title                  object
# cast                            object
# director                        object
# tagline                         object
# runtime                          int64
# genres                          object
# production_companies            object
# release_date            datetime64[ns]
# release_year                     int64
# dtype: object

# %% [markdown]
# <b>QUESTION 1: Which are the movies with the third lowest and third highest budget?</b>

# %%
tmdb_data.nlargest(3, ['budget']).iloc[[-1]]
# Out:
#          budget    revenue                            original_title  \
# 7387  300000000  961000000  Pirates of the Caribbean: At World's End
#
#                                                    cast        director  \
# 7387  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...  Gore Verbinski
#
#                                              tagline  runtime  \
# 7387  At the end of the world, the adventure begins.      169
#
#                         genres  \
# 7387  Adventure|Fantasy|Action
#
#                                    production_companies release_date  \
# 7387  Walt Disney Pictures|Jerry Bruckheimer Films|S...   2007-05-19
#
#       release_year
# 7387          2007

# %%
tmdb_data.nsmallest(3, ['budget']).iloc[[-1]]
# Out:
#       budget  revenue original_title  \
# 8944       2       16   Death Wish 2
#
#                                                    cast        director  \
# 8944  Charles Bronson|Jill Ireland|Vincent Gardenia|...  Michael Winner
#
#                                                 tagline  runtime  \
# 8944  First His Wife. Now His Daughter. It's Time To...       88
#
#                      genres production_companies release_date  release_year
# 8944  Action|Crime|Thriller         Cannon Films   1982-02-20          1982

# %% [markdown]
# <b>QUESTION 2: What is the average number of words in movies title between the year 2000-2005?</b>

# %%
from statistics import mean 
from fractions import Fraction as fr

# %%
small_df = tmdb_data[['original_title', 'release_year']]
result = small_df[(small_df['release_year'] >= 2000) & (small_df['release_year'] <= 2005)]
word = pd.DataFrame(result)
word.head()
# Out:
#                                          original_title  release_year
# 2633  The Lord of the Rings: The Fellowship of the Ring          2001
# 2634           Harry Potter and the Philosopher's Stone          2001
# 2635                                   Mulholland Drive          2001
# 2636                                       Donnie Darko          2001
# 2637                                     Monsters, Inc.          2001

# %%
word['number_of_words'] = word.original_title.apply(lambda x: len(x.split()))
print(word)
# Out:
#                                          original_title  release_year  \
# 2633  The Lord of the Rings: The Fellowship of the Ring          2001
# 2634           Harry Potter and the Philosopher's Stone          2001
# 2635                                   Mulholland Drive          2001
# 2636                                       Donnie Darko          2001
# 2637                                     Monsters, Inc.          2001
# 2638                       A.I. Artificial Intelligence          2001
# 2639                                              Shrek          2001
# 2640                              Bridget Jones's Diary          2001
# 2641                                     Ocean's Eleven          2001
# 2642                                       Pearl Harbor          2001
# 2643                                  The Mummy Returns          2001
# 2644                          Atlantis: The Lost Empire          2001
# ...

# %%
word['number_of_words'].mean()
# Out:
# 2.6904458598726113

# %% [markdown]
# <b>QUESTION 3:Which are the movies with most and least earned revenue?</b>

# %%
import pprint
#defining the function
def calculate(column):
    #for highest earned profit
    high=tmdb_data[column].idxmax()
    high_details=pd.DataFrame(tmdb_data.loc[high])
    
    #for lowest earned profit
    low= tmdb_data[column].idxmin()
    low_details=pd.DataFrame(tmdb_data.loc[low])
    
    #collectin data in one place
    info=pd.concat([high_details, low_details], axis=1)
    
    return info
# we will call the same function **calculate(column)** again for this analysis
calculate('revenue')
# Out:
#                                                                    1386  \
# budget                                                        237000000
# revenue                                                      2781505060
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                  James Cameron
# tagline                                     Enter the World of Pandora.
# runtime                                                             162
# genres                         Action|Adventure|Fantasy|Science Fiction
# production_companies  Ingenious Film Partners|Twentieth Century Fox ...
# release_date                                        2009-12-10 00:00:00
# release_year                                                       2009
#
#                                                                    5067
# ...

# %% [markdown]
# <b>QUESTION 4: What is the average runtime of movies in the year 2006?</b>

# %%
small_df = tmdb_data[['original_title', 'release_year', 'runtime']]
run = small_df[(small_df['release_year'] == 2006)]
run = pd.DataFrame(run)
run.head()
# Out:
#                                   original_title  release_year  runtime
# 6554                       Underworld: Evolution          2006      106
# 6555  Pirates of the Caribbean: Dead Man's Chest          2006      151
# 6556                                        Cars          2006      117
# 6557                               Casino Royale          2006      144
# 6558                           The Da Vinci Code          2006      149

# %%
run['runtime'].mean()
# Out:
# 108.18934911242603

# %% [markdown]
# <b>QUESTION 5: Name any 3 production companies which have invested money in worse revenue movies?</b>

# %%
# creating a seperate list of revenue and budget column


#this will replace all the value from '0' to NAN in the list
tmdb_data[temp_list] = tmdb_data[temp_list].replace(0, np.NAN)

#Removing all the row which has NaN value in temp_list 
tmdb_data.dropna(subset = temp_list, inplace = True)

# %%
nf=tmdb_data.nsmallest(50, ['revenue'])

# %%
nf['production_companies'].value_counts()[:3].index.tolist()
# Out:
# ['Sahara One Motion Pictures',
#  'New Line Cinema|Golden Harvest Company',
#  'Pathe Productions|Red Turtle']
